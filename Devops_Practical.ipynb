# %% [markdown]
# **3) How to install git in ec2 instance (AWS Linux)**
#
# ```
# sudo yum install git -y
# ```
#
#
#
# > In Ubuntu
#
# ```
# sudo apt install git
# ```
#
# To check version
#
#
# ```
# git --version
# ```

# %% [markdown]
# **9) To Perform various GIT operations on local and Remote repositories**
#
#
#
# ```
# git clone 'https or ssh link of your github repo'
# ```
#
#
# ```
# git remote add bhanu 'link of repo'
# ```
#
#
# Now create a new file then push
#
# ```
# git add .
# git commit -m 'Initial commit'
# ```
# ```
# git config --global --edit
# ```
# Added username and password from terminal
#
# ```
# git push origin master
# ```
# * If branch name is 'master' else 'main'
#
# > If in return it asks username and password:
# >> Then, In place of username add ur github username and in place of password add personal token key
# >>> Note: Personal token key should have all previlages (all check while creating)

# %% [markdown]
# 5. **Create slave node in Jnekins**
# 6. **Assign project to slave node and build project**

# %% [markdown]
# 1)Create node by clicking onto manage nodes and clouds
#
# 2)In Configure global settings In Agents
#
# 3)

# %% [markdown]
# Q8)** Build pipeline projects in jenkins**
#
#
# Steps:
#
# 1) Create pipeline from new item and save and change script to hello world and then check the console.
#
# 2)after that click on configure and change the pipeline script to
# ```
# pipeline
# {
#     agent any
#
#     stages
#     {
#         stage('Build')
#         {
#             steps {
#                 echo 'Building App'
#             }
#         }
#         stage('Test')
#         {
#             steps {
#                 echo 'Testing App'
#             }
#         }
#         stage('Deploy')
#         {
#             steps {
#                 echo 'Deploying App'
#             }
#         }
#     }
# }
#
#
# ```
# 4) Copy farhan git repo (jenkinsfile) link
# 3) ![WhatsApp Image 2022-11-13 at 14.27.57.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2022-11-13 at 14.27.44.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2022-11-13 at 14.27.25.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2022-11-13 at 14.27.15.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 7) Run Selenium Tests in Jenkins Using Maven
#
# Steps:
#
# 1) First check Maven-Integretion is downloaded or not in manage plugins
#
# 2) Search for repo "jleetutorial" on github and copy the https path and paste it in SCM
#
# 3) copy the pom.xml file an dpaste it on desktop and also write "test" in goals
# and options under build and apply and save
